# 4    262.198409    11.288155  41.557842   7.470398  322.416597
# ..          ...          ...        ...        ...         ...
# 995  208.486255    28.189485  34.584366   7.966478  431.674874
# 996  155.933920    31.681474  28.856730   2.897871  259.012697
# 997  231.893166    41.463075  50.979587  14.676836  474.419799
# 998  150.734284    24.434990  91.759379   2.064906  259.012697
# 999   53.320675    29.860292  19.403229  14.013190  124.227394
#
# [1000 rows x 11 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df['Weekday'] = df['Date'].dt.dayofweek
df.head(5)
# Out:
#         Date       PM2.5        PM10         NO2        SO2        CO  \
# 0 2022-01-01  203.412225  108.863806   56.032608  67.924893  2.523531
# 1 2022-01-02  380.778579  280.112455   53.160866  80.074777  4.046618
# 2 2022-01-03  295.477637  269.153978  181.719643  26.545854  3.824789
# 3 2022-01-04  243.476809  269.153978   53.661509  63.237662  0.854110
# 4 2022-01-05   70.847270  407.149351   58.030197  58.031106  0.831322
#
#            O3  Temperature   Humidity  WindSpeed         AQI  Year  Month  \
# 0  124.154301    30.930278  13.491951  10.943885  458.517445  2022      1
# 1  147.296341    11.895454  26.809528  10.465604  272.173031  2022      1
# 2  257.818744    39.895783  84.812122   1.888436  367.956930  2022      1
# 3  108.601272    29.524650  79.009152  13.877300  229.303183  2022      1
# 4  262.198409    11.288155  41.557842   7.470398  322.416597  2022      1
#
#    Day  Weekday
# 0    1        5
# 1    2        6
# 2    3        0
# 3    4        1
# 4    5        2

# %%
df.drop('Date', axis=1, inplace=True)

# %%
def categorize_aqi(aqi):
    if aqi <= 50:
        return "Good"
    elif aqi <= 100:
        return "Satisfactory"
    elif aqi <= 200:
        return "Moderate"
    elif aqi <= 300:
        return "Poor"
    elif aqi <= 400:
        return "Very Poor"
    else:
        return "Severe"

# %%
df['AQI_Category'] = df['AQI'].apply(categorize_aqi)

# %%
df.head(5)
# Out:
#         PM2.5        PM10         NO2        SO2        CO          O3  \
# 0  203.412225  108.863806   56.032608  67.924893  2.523531  124.154301
# 1  380.778579  280.112455   53.160866  80.074777  4.046618  147.296341
# 2  295.477637  269.153978  181.719643  26.545854  3.824789  257.818744
# 3  243.476809  269.153978   53.661509  63.237662  0.854110  108.601272
# 4   70.847270  407.149351   58.030197  58.031106  0.831322  262.198409
#
#    Temperature   Humidity  WindSpeed         AQI  Year  Month  Day  Weekday  \
# 0    30.930278  13.491951  10.943885  458.517445  2022      1    1        5
# 1    11.895454  26.809528  10.465604  272.173031  2022      1    2        6
# 2    39.895783  84.812122   1.888436  367.956930  2022      1    3        0
# 3    29.524650  79.009152  13.877300  229.303183  2022      1    4        1
# 4    11.288155  41.557842   7.470398  322.416597  2022      1    5        2
#
#   AQI_Category
# 0       Severe
# 1         Poor
# 2    Very Poor
# 3         Poor
# 4    Very Poor

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['AQI_Category'] = le.fit_transform(df['AQI_Category'])

# %%
df.head(5)
# Out:
#         PM2.5        PM10         NO2        SO2        CO          O3  \
# 0  203.412225  108.863806   56.032608  67.924893  2.523531  124.154301
# 1  380.778579  280.112455   53.160866  80.074777  4.046618  147.296341
# 2  295.477637  269.153978  181.719643  26.545854  3.824789  257.818744
# 3  243.476809  269.153978   53.661509  63.237662  0.854110  108.601272
# 4   70.847270  407.149351   58.030197  58.031106  0.831322  262.198409
#
#    Temperature   Humidity  WindSpeed         AQI  Year  Month  Day  Weekday  \
# 0    30.930278  13.491951  10.943885  458.517445  2022      1    1        5
# 1    11.895454  26.809528  10.465604  272.173031  2022      1    2        6
# 2    39.895783  84.812122   1.888436  367.956930  2022      1    3        0
# 3    29.524650  79.009152  13.877300  229.303183  2022      1    4        1
# 4    11.288155  41.557842   7.470398  322.416597  2022      1    5        2
#
#    AQI_Category
# 0             4
# 1             2
# 2             5
# 3             2
# 4             5

# %%
X = df.drop(['AQI', 'AQI_Category'], axis=1)
y = df['AQI_Category']

# %%
df.head(5)
# Out:
#         PM2.5        PM10         NO2        SO2        CO          O3  \
# 0  203.412225  108.863806   56.032608  67.924893  2.523531  124.154301
# 1  380.778579  280.112455   53.160866  80.074777  4.046618  147.296341
# 2  295.477637  269.153978  181.719643  26.545854  3.824789  257.818744
# 3  243.476809  269.153978   53.661509  63.237662  0.854110  108.601272
# 4   70.847270  407.149351   58.030197  58.031106  0.831322  262.198409
#
#    Temperature   Humidity  WindSpeed         AQI  Year  Month  Day  Weekday  \
# 0    30.930278  13.491951  10.943885  458.517445  2022      1    1        5
# 1    11.895454  26.809528  10.465604  272.173031  2022      1    2        6
# 2    39.895783  84.812122   1.888436  367.956930  2022      1    3        0
# 3    29.524650  79.009152  13.877300  229.303183  2022      1    4        1
# 4    11.288155  41.557842   7.470398  322.416597  2022      1    5        2
#
#    AQI_Category
# 0             4
# 1             2
# 2             5
# 3             2
# 4             5

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)
print(X_scaled_df)
# Out:
#         PM2.5      PM10       NO2       SO2        CO        O3  Temperature  \
# 0    0.028692 -1.175412 -0.863624  0.675841  0.000294 -0.396249     0.557061
# 1    1.683196  0.119395 -0.916889  1.134479  1.140278 -0.104042    -1.175511
# 2    0.887494  0.036538  1.467593 -0.886148  0.974245  1.291492     1.373112
# 3    0.402421  0.036538 -0.907603  0.498906 -1.249217 -0.592633     0.429119
# 4   -1.207897  1.079919 -0.826573  0.302367 -1.266272  1.346792    -1.230788
# ..        ...       ...       ...       ...       ...       ...          ...
# 995 -1.442316  0.536958  1.319452 -0.177211  0.000294  0.668585     0.307591
# 996  1.561684  1.624504 -1.241338 -0.022216 -1.375815  0.005023     0.625436
# 997 -1.277746 -1.597043 -0.689720 -0.353058  0.000294  0.964137     1.515769
# 998  1.681461 -1.640243 -0.761124  0.147715  1.178101 -0.060632    -0.034148
# 999 -0.152927 -0.823177  1.341581 -1.215761  0.376998 -1.290644     0.459670
#
#      Humidity  WindSpeed      Year     Month       Day   Weekday
# 0   -1.633634   0.875438 -1.143853 -1.542765 -1.671743  1.000125
# 1   -1.085452   0.752348 -1.143853 -1.542765 -1.557802  1.499938
# 2    1.302066  -1.455078 -1.143853 -1.542765 -1.443861 -1.498938
# 3    1.063203   1.630384 -1.143853 -1.542765 -1.329920 -0.999126
# 4   -0.478378  -0.018501 -1.143853 -1.542765 -1.215979 -0.499313
# ..        ...        ...       ...       ...       ...       ...
# 995 -0.765422   0.109171  1.383999  0.877259  0.721019  1.499938
# 996 -1.001184  -1.195289  1.383999  0.877259  0.834960 -1.498938
# 997 -0.090557   1.836153  1.383999  0.877259  0.948901 -0.999126
# 998  1.588031  -1.409662  1.383999  0.877259  1.062842 -0.499313
# 999 -1.390312   1.665357  1.383999  0.877259  1.176783  0.000500
#
# [1000 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.svm import SVC

svm = SVC(probability=True)
svm.fit(X_train, y_train)
# Out:
# SVC(probability=True)

# %%
y_pred_lr = lr.predict(X_test)
y_pred_knn = knn.predict(X_test)
y_pred_svm = svm.predict(X_test)

# %%
from sklearn.metrics import classification_report

print("Logistic Regression:\n", classification_report(y_test, y_pred_lr))
print("KNN:\n", classification_report(y_test, y_pred_knn))
print("SVM:\n", classification_report(y_test, y_pred_svm))
# Out:
# Logistic Regression:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        13
#            1       0.10      0.03      0.04        40
#            2       0.30      0.82      0.44        62
#            3       0.00      0.00      0.00        13
#            4       0.15      0.06      0.09        34
#            5       0.00      0.00      0.00        38
#
#     accuracy                           0.27       200
#    macro avg       0.09      0.15      0.09       200
# weighted avg       0.14      0.27      0.16       200
#
# KNN:
#                precision    recall  f1-score   support
#
#            0       0.18      0.15      0.17        13
#            1       0.18      0.23      0.20        40
#            2       0.33      0.47      0.39        62
#            3       0.00      0.00      0.00        13
#            4       0.25      0.18      0.21        34
#            5       0.10      0.05      0.07        38
#
#     accuracy                           0.24       200
#    macro avg       0.17      0.18      0.17       200
# weighted avg       0.21      0.24      0.22       200
#
# SVM:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        13
#            1       0.00      0.00      0.00        40
#            2       0.33      0.90      0.48        62
#            3       0.00      0.00      0.00        13
#            4       0.15      0.06      0.09        34
#            5       0.29      0.05      0.09        38
#
#     accuracy                           0.30       200
#    macro avg       0.13      0.17      0.11       200
# weighted avg       0.18      0.30      0.18       200
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_pred_lr))
# Out:
# [[ 0  1 11  0  1  0]
#  [ 0  1 35  0  2  2]
#  [ 0  3 51  0  5  3]
#  [ 0  0 11  0  2  0]
#  [ 0  4 24  0  2  4]
#  [ 0  1 36  0  1  0]]

# %%
from sklearn.metrics import accuracy_score

print("LR Accuracy:", accuracy_score(y_test, y_pred_lr))
print("KNN Accuracy:", accuracy_score(y_test, y_pred_knn))
print("SVM Accuracy:", accuracy_score(y_test, y_pred_svm))
# Out:
# LR Accuracy: 0.27
# KNN Accuracy: 0.24
# SVM Accuracy: 0.3

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_auc_score

y_test_bin = label_binarize(y_test, classes=[0,1,2,3,4,5])

y_prob = svm.predict_proba(X_test)

roc_score = roc_auc_score(y_test_bin, y_prob, multi_class='ovr')
print("ROC AUC Score:", roc_score)
# Out:
# ROC AUC Score: 0.5280658452708966
